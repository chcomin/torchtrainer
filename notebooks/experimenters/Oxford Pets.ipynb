# %%
import _train as train

params = {
    '--dataset-name':'oxford_pets',
    '--experiment-path':'experiments/no_name_experiment',
    '--run-name':'no_name_run',
    '--model-name':'encoder_decoder',
    '--bs-train':32,
    '--bs-valid':8,
    '--num-epochs':3,
    '--lr':0.01,
    '--weight-decay':1e-3,
    '--resize-size':384,  
    '--seed':0,
    '--device':'cuda',
    '--num-workers':0,
}

runner = train.train(params)

# %%
runner
